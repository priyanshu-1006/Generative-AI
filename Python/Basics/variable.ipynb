# %% [markdown]
# ## Variables

# %% [markdown]
# # variables are the elements in python that can be used to store data into it or values into it or they can be reffered as containers as well
# # Variables as per its name, data can vary that we want to store into it and once declared we can alter the value.

# %%
age=23
Name="Priyanshu Chaurasia"
Height=5.11
is_true=True

# %%
age
# Out:
# 23

# %%
Height
# Out:
# 5.11

# %%
print(Name)
# Out:
# Priyanshu Chaurasia

# %%
print("Name is : " +Name)
# Out:
# Name is : Priyanshu Chaurasia

# %% [markdown]
# ## Comments
# # comments is a statement in python program that we dont want to be executable
#
# # Interpreter - Interpreter is used for execute codes line by line
