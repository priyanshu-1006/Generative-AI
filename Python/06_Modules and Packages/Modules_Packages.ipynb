# %% [markdown]
# # Modules and Packages

# %%
def addition(num1, num2):
    return num1 + num2

# %%
addition(5, 10)
# Out:
# 15

# %% [markdown]
# -------------

# %% [markdown]
# ### I want to use this logic of the function in this file into the other files

# %%
import math

# %%
math.sqrt(16)
# Out:
# 4.0

# %%
### How complex the logic of a square root function is going to be

# %% [markdown]
# ----------

# %% [markdown]
# ## Module
#
# #### A module in python is simply a file containing python code (function, classes or variables) that can be imported and used in other programs

# %% [markdown]
# ------------

# %% [markdown]
# ###  Numpy
# #### -----> Numpy Module is going to help us out with applying scientific calculation on the array and we can store our data by consuming less space and we can apply the operations with our array a bit more faster as compared to those of the list
#
# #### -----> We can do it in Numpy just because Numpy is having the collection of functions and attributes which can help us to work efficiently with the array

# %% [markdown]
# ---------

# %% [markdown]
# ### Pandas
#
# #### ----> Pandas we can use when we are going to work with the dataset for cleaning, pre processing, EDA, analysis with plotting as well

# %%
import math
math.sqrt(16)
# Out:
# 4.0

# %%
from math import sqrt
sqrt(16)
# Out:
# 4.0

# %%
from math import *
print(pi)
# Out:
# 3.141592653589793

# %%
## A Module:

## 1. A module helps in code organisation
## 2. A module helps in code reusability
## 3. A module helps in code clean and maintainability

# %%
print(cos(90))
# Out:
# -0.4480736161291701

# %%
import numpy

# %%
list_items=[[1, 2, 3], [4, 5, 6], [7, 8, 9]]
numpy_array=numpy.array(list_items)
type(numpy_array)
print(numpy_array)
# Out:
# [[1 2 3]
#  [4 5 6]
#  [7 8 9]]

# %%
type(numpy_array)
# Out:
# numpy.ndarray

# %%
pip install seaborn
# Out:
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...
#   Using cached contourpy-1.3.3-cp313-cp313-win_amd64.whl.metadata (5.5 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached kiwisolver-1.5.0-cp313-cp313-win_amd64.whl.metadata (5.2 kB)
# ...
#   Using cached pillow-12.2.0-cp313-cp313-win_amd64.whl.metadata (9.0 kB)
# ...
#   Using cached pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# ...
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# ...
#    ---------------------------------------- 0.0/8.2 MB ? eta -:--:--
#    -------------------------------------- - 7.9/8.2 MB 39.4 MB/s eta 0:00:01
#    ---------------------------------------- 8.2/8.2 MB 34.3 MB/s  0:00:00
# Using cached contourpy-1.3.3-cp313-cp313-win_amd64.whl (226 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# ...
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 2.3/2.3 MB 26.4 MB/s  0:00:00
# ...

# %% [markdown]
# ##### I am trying to create my own library and in this library i want the functions and the attribute to be created on my own

# %%
## __init__.py__ file is used to make a directory a package. It can be an empty file or it can contain code that needs to be executed when the package is imported.

## File helps us out in defining our packages and initialising there namesppaces.

# %%
## __init__.py__ file can remain empty and its completely fine but this file has to be their when we will be creating our new packages into the package folder

# %%
from package.mathematics import *

# %%
division(10, 2)
# Out:
# 5.0

# %%
division(10, 0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 division(10, 0)
#
# File c:\Users\priya\OneDrive\Desktop\CODING\Generative AI Course\Python\Modules and Packages\package\mathematics.py:15, in division(a, b)
#      13 def division(a, b):
#      14     if b == 0:
# ---> 15         raise ValueError("Denominator cannot be zero.")
#      16     return a / b
#
# ValueError: Denominator cannot be zero.

# %%
from package.subpackage.sum import *

# %%
addi(5, 10)
# Out:
# 15
